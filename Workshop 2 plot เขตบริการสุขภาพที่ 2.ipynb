# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/hypertension_all.csv')
df
# Out:
#     เขตบริการสุขภาพ        จังหวัด    2559    2560    2561  ประชากรกลางปี
# 0                 0  กรุงเทพมหานคร  133085  128883  136418        5575104
# 1                 1      เชียงใหม่   33566   33071   35546        1620100
# 2                 1          ลำพูน    5616    5406    6992         403330
# 3                 1          ลำปาง   19044   21150   22130         742078
# 4                 1           แพร่   13974   15019   15262         445766
# ..              ...            ...     ...     ...     ...            ...
# 72               12           ตรัง   15653   16467   17421         641755
# 73               12         พัทลุง   10654   11398   12646         524618
# 74               12        ปัตตานี    7287    7513    7974         712310
# 75               12           ยะลา    7476    8652    8359         528350
# 76               12       นราธิวาส   13131   14736   17594         798098
#
# [77 rows x 6 columns]

# %%
df['เขตบริการสุขภาพ'] == 2
df
# Out:
#     เขตบริการสุขภาพ        จังหวัด    2559    2560    2561  ประชากรกลางปี
# 0                 0  กรุงเทพมหานคร  133085  128883  136418        5575104
# 1                 1      เชียงใหม่   33566   33071   35546        1620100
# 2                 1          ลำพูน    5616    5406    6992         403330
# 3                 1          ลำปาง   19044   21150   22130         742078
# 4                 1           แพร่   13974   15019   15262         445766
# ..              ...            ...     ...     ...     ...            ...
# 72               12           ตรัง   15653   16467   17421         641755
# 73               12         พัทลุง   10654   11398   12646         524618
# 74               12        ปัตตานี    7287    7513    7974         712310
# 75               12           ยะลา    7476    8652    8359         528350
# 76               12       นราธิวาส   13131   14736   17594         798098
#
# [77 rows x 6 columns]

# %%
df[df['เขตบริการสุขภาพ']==2][['2559','2560','2561']].head(10).plot.bar(stacked = True)
# Out:
# <AxesSubplot:>
